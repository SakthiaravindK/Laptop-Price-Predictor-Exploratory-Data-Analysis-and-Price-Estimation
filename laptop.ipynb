# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings

# %%
laptop_df=pd.read_csv("laptopData.csv")
laptop_df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
laptop_df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
laptop_df.tail()
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# ...

# %%
laptop_df.shape
# Out:
# (1303, 12)

# %%
laptop_df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
laptop_df.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %%
set(laptop_df)
# Out:
# {'Company',
#  'Cpu',
#  'Gpu',
#  'Inches',
#  'Memory',
#  'OpSys',
#  'Price',
#  'Ram',
#  'ScreenResolution',
#  'TypeName',
#  'Unnamed: 0',
#  'Weight'}

# %%
laptop_df.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            50
# Inches              83
# ScreenResolution    30
# Cpu                 30
# Ram                 44
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              44
# Price               30
# dtype: int64

# %%
# Percentage of missing values in each column corresponding to total number of records

round(100*(laptop_df.isnull().sum()/len(laptop_df.index)), 2).sort_values(ascending=False)

# (889/39717)*100
# Out:
# Inches              6.37
# TypeName            3.84
# Ram                 3.38
# Weight              3.38
# Unnamed: 0          2.30
# Company             2.30
# ScreenResolution    2.30
# Cpu                 2.30
# Memory              2.30
# Gpu                 2.30
# OpSys               2.30
# Price               2.30
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(laptop_df.isnull(), cbar=False, cmap='Reds')
plt.title("Missing Values Heatmap")
plt.show()

# %%
# Convert to float and fill NaN with mean
laptop_df['Weight'] = pd.to_numeric(laptop_df['Weight'].astype(str).str.replace('kg', '', regex=False), errors='coerce')
laptop_df['Weight'] = laptop_df['Weight'].fillna(laptop_df['Weight'].mean())

# %%
# Step 1: Convert Inches to numeric (force conversion, invalid values become NaN)
laptop_df['Inches'] = pd.to_numeric(laptop_df['Inches'], errors='coerce')

# Step 2: Now fill missing values with the median
laptop_df['Inches'] = laptop_df['Inches'].fillna(laptop_df['Inches'].median())
laptop_df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0            0.0   Apple           Ultrabook    13.3
# 1            1.0   Apple           Ultrabook    13.3
# 2            2.0      HP            Notebook    15.6
# 3            3.0   Apple           Ultrabook    15.4
# 4            4.0   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298      1298.0  Lenovo  2 in 1 Convertible    14.0
# 1299      1299.0  Lenovo  2 in 1 Convertible    13.3
# 1300      1300.0  Lenovo            Notebook    65.4
# 1301      1301.0      HP            Notebook    15.6
# 1302      1302.0    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
laptop_df_cleaned = laptop_df.dropna()

# %%
laptop_df['OpSys'] = laptop_df['OpSys'].fillna(laptop_df['OpSys'].mode()[0])
laptop_df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
laptop_df['Gpu'] =laptop_df['Gpu'].fillna("Unknown GPU")

# %%
laptop_df.isnull().sum()  # Should show all zeros
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            50
# Inches               0
# ScreenResolution    30
# Cpu                 30
# Ram                  0
# Memory              30
# Gpu                  0
# OpSys                0
# Weight               0
# Price               30
# dtype: int64

# %%
laptop_df['Company'] = laptop_df['Company'].replace('Apple', 'FruitTech')

# %%
laptop_df.loc[laptop_df['Price'] > 100000, 'Company'] = 'LuxuryTech'

# %%
laptop_df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
laptop_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# Categorical columns – fill with mode
laptop_df['Company'] = laptop_df['Company'].fillna(laptop_df['Company'].mode()[0])
laptop_df['TypeName'] = laptop_df['TypeName'].fillna(laptop_df['TypeName'].mode()[0])
laptop_df['Cpu'] = laptop_df['Cpu'].fillna(laptop_df['Cpu'].mode()[0])
laptop_df['ScreenResolution'] = laptop_df['ScreenResolution'].fillna(laptop_df['ScreenResolution'].mode()[0])
laptop_df['Memory'] = laptop_df['Memory'].fillna(laptop_df['Memory'].mode()[0])
laptop_df['Price'] = laptop_df['Price'].fillna(laptop_df['Price'].median())

# %%
laptop_df
# Out:
#               Company            TypeName  Inches  \
# 0           TechWorld           Ultrabook    13.3
# 1           FruitTech           Ultrabook    13.3
# 2     Hewlett-Packard            Notebook    15.6
# 3          LuxuryTech           Ultrabook    15.4
# 4           FruitTech           Ultrabook    13.3
# ...               ...                 ...     ...
# 1298     Lenovo Group  2 in 1 Convertible    14.0
# 1299     Lenovo Group  2 in 1 Convertible    13.3
# 1300     Lenovo Group            Notebook    65.4
# 1301  Hewlett-Packard            Notebook    15.6
# 1302             Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# ...

# %%
# Remove "GB", convert to float
laptop_df['Ram'] = laptop_df['Ram'].astype(str).str.replace("GB", "", regex=False).astype(float)

# Fill missing values with median RAM
laptop_df['Ram'] = laptop_df['Ram'].fillna(laptop_df['Ram'].median())

# %%
laptop_df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
laptop_df
# Out:
#               Company            TypeName  Inches  \
# 0           TechWorld           Ultrabook    13.3
# 1           FruitTech           Ultrabook    13.3
# 2     Hewlett-Packard            Notebook    15.6
# 3          LuxuryTech           Ultrabook    15.4
# 4           FruitTech           Ultrabook    13.3
# ...               ...                 ...     ...
# 1298     Lenovo Group  2 in 1 Convertible    14.0
# 1299     Lenovo Group  2 in 1 Convertible    13.3
# 1300     Lenovo Group            Notebook    65.4
# 1301  Hewlett-Packard            Notebook    15.6
# 1302             Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# ...

# %%
# Reload the original dataset
original_df = pd.read_csv("laptopData.csv")  # Or your correct file path

# Replace the 'Ram' column in your cleaned DataFrame with the original values
laptop_df['Ram'] = original_df['Ram']

# %%
laptop_df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter top 10 most frequent CPU models
top_cpus =laptop_df['Cpu'].value_counts().head(10).index

# Filter dataset to include only those top 10 CPUs
filtered_laptop_df =laptop_df[laptop_df['Cpu'].isin(top_cpus)]

# Create the box plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=filtered_laptop_df, x='Cpu', y='Price')
plt.title("Price Distribution by Top 10 CPU Models")
plt.xlabel("CPU Model")
plt.ylabel("Price")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))

# Histogram with KDE line
sns.histplot(data=laptop_df, x='Price', bins=30, kde=True, color='skyblue', edgecolor='black')

plt.title("Distribution of Laptop Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot of RAM vs Price
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Ram', y='Price', data=laptop_df, color='orange', marker='x')

plt.title("RAM vs Price")
plt.xlabel("RAM (GB)")
plt.ylabel("Price")
plt.show()

# %%
# Remove 'kg' and convert to float
laptop_df['Weight'] = (
    laptop_df['Weight']
    .astype(str)                            # Convert all values to string
    .str.replace('kg', '', regex=False)     # Remove 'kg'
    .str.strip()                            # Remove extra spaces
    .astype(float)                          # Convert to float
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a correlation matrix
corr = laptop_df[['Price', 'Ram', 'Weight']].corr()

# Plot heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title("Correlation Heatmap: Price, RAM, Screen Size, Weight")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Extract GPU brand from the full GPU string
laptop_df['Gpu_Brand'] = laptop_df['Gpu'].astype(str).str.split().str[0]

# Compute average price per GPU brand
avg_price_by_gpu = laptop_df.groupby('Gpu_Brand')['Price'].mean().sort_values(ascending=False).head(10)

# Plot the bar chart
plt.figure(figsize=(10, 5))
sns.barplot(x=avg_price_by_gpu.index, y=avg_price_by_gpu.values, palette='muted')

plt.title("Top 10 GPU Brands by Average Laptop Price")
plt.xlabel("GPU Brand")
plt.ylabel("Average Price")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sakth\AppData\Local\Temp\ipykernel_23720\1275290452.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_by_gpu.index, y=avg_price_by_gpu.values, palette='muted')

# %%
#1. Univariate Analysis
for col in ['Inches', 'Ram', 'Price']:
    plt.figure(figsize=(6, 4))
    sns.histplot(laptop_df[col], kde=True, bins=30, color='orange')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

print(df[['Inches', 'Ram', 'Price']].describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 12
#       9     plt.tight_layout()
#      10     plt.show()
# ---> 12 print(df[['Inches', 'Ram', 'Price']].describe())
#
# NameError: name 'df' is not defined

# %%
#2. Bivariate Analysis

# RAM vs Price
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Ram', y='Price', data=laptop_df, color='green')
plt.title("RAM vs Price")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# CPU vs Price (top 10)
top_cpus = laptop_df['Cpu'].value_counts().head(10).index
plt.figure(figsize=(10, 5))
sns.boxplot(data=laptop_df[laptop_df['Cpu'].isin(top_cpus)], x='Cpu', y='Price')
plt.xticks(rotation=45)
plt.title("Price Distribution by Top 10 CPUs")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
laptop_df = pd.read_csv("laptopData.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#Univariate Analysis
# Distribution of Screen Size
sns.histplot(laptop_df['Inches'], kde=True)
plt.title('Distribution of Screen Size')
plt.xlabel('Screen Size (inches)')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#Univariate Analysis
# Distribution of RAM
sns.countplot(x='Ram', data=laptop_df)
plt.title('RAM Distribution')
plt.xlabel('RAM ')
plt.ylabel('Count')
plt.show()

# %%
# Distribution of Price
sns.histplot(laptop_df['Price'], kde=True)
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Price vs RAM
sns.boxplot(x='Ram', y='Price', data=laptop_df)
plt.title('Price vs RAM')
plt.xlabel('RAM ')
plt.ylabel('Price')
plt.show()
# Company vs Price
plt.figure(figsize=(12, 6))
sns.boxplot(x='Company', y='Price', data=laptop_df)
plt.xticks(rotation=45)
plt.title('Price Variation by Company')
plt.show()

# %%
#1. Histogram
# Price Distribution
sns.histplot(laptop_df['Price'], kde=True)
plt.title('Laptop Price Distribution')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
#Descriptive Statistics
import pandas as pd

# Assuming 'laptop_df' is your DataFrame
# Display descriptive statistics
print(laptop_df.describe())

# Mode for categorical variables
print(laptop_df.mode().iloc[0])
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000
# Unnamed: 0                                 0.0
# Company                                 Lenovo
# TypeName                              Notebook
# Inches                                    15.6
# ScreenResolution             Full HD 1920x1080
# Cpu                 Intel Core i5 7200U 2.5GHz
# Ram                                        8GB
# Memory                               256GB SSD
# Gpu                      Intel HD Graphics 620
# OpSys                               Windows 10
# Weight                                   2.2kg
# Price                                 58554.72
# Name: 0, dtype: object

# %%
laptop_df.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %%
#Inferential Statistics
#Independent Two-Sample t-Test
from scipy.stats import ttest_ind

# Filter data for 8GB and 16GB RAM
price_8gb = laptop_df[laptop_df['Ram'] == 8]['Price']
price_16gb = laptop_df[laptop_df['Ram'] == 16]['Price']

# Perform t-test
t_stat, p_value = ttest_ind(price_8gb, price_16gb, equal_var=False)

print(f"T-statistic: {t_stat}, P-value: {p_value}")
#decision:
alpha=0.05
if p_value<alpha :
    print("reject the null hupothesis")
else:
    print("fails to reject the null hypothesis")
# Out:
# T-statistic: -16.822295145343546, P-value: 4.358569023095348e-44
# reject the null hupothesis

# %%
# Chi-Square Test of Independence
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(laptop_df['Company'], laptop_df['OpSys'])

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi2 Statistic: {chi2}, P-value: {p}")
#decision:
alpha=0.05
if p_value<alpha :
    print("reject the null hupothesis")
else:
    print("fails to reject the null hypothesis")
# Out:
# Chi2 Statistic: 2240.388653310108, P-value: 0.0
# reject the null hupothesis

# %%
import pandas as pd

# Load your dataset
laptop_df = pd.read_csv('laptopData.csv')  # Replace with your actual file path

# Calculate Q1 (25th percentile) and Q3 (75th percentile) for the 'Price' column
Q1 = laptop_df['Price'].quantile(0.25)
Q3 = laptop_df['Price'].quantile(0.75)
IQR = Q3 - Q1  # Interquartile Range

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
laptop_df_cleaned = laptop_df[(laptop_df['Price'] >= lower_bound) & (laptop_df['Price'] <= upper_bound)]

# Display the number of records before and after outlier removal
print(f"Original dataset size: {laptop_df.shape[0]}")
print(f"Cleaned dataset size: {laptop_df_cleaned.shape[0]}")
# Out:
# Original dataset size: 1303
# Cleaned dataset size: 1245

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Boxplot before handling outliers
plt.figure(figsize=(10, 5))
sns.boxplot(x=laptop_df['Price'])
plt.title('Boxplot of Laptop Prices (Before Handling Outliers)')
plt.show()

# Boxplot after removing outliers
plt.figure(figsize=(10, 5))
sns.boxplot(x=laptop_df_cleaned['Price'])
plt.title('Boxplot of Laptop Prices (After Removing Outliers)')
plt.show()

# %%
# Descriptive Statistics
import pandas as pd

# Load your dataset
laptop_df = pd.read_csv('laptopData.csv')  

# Display descriptive statistics for numerical columns
print(laptop_df.describe())

# Calculate mode for each column
print(laptop_df.mode().iloc[0])
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000
# Unnamed: 0                                 0.0
# Company                                 Lenovo
# TypeName                              Notebook
# Inches                                    15.6
# ScreenResolution             Full HD 1920x1080
# Cpu                 Intel Core i5 7200U 2.5GHz
# Ram                                        8GB
# Memory                               256GB SSD
# Gpu                      Intel HD Graphics 620
# OpSys                               Windows 10
# Weight                                   2.2kg
# Price                                 58554.72
# Name: 0, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for 'Price'
plt.figure(figsize=(8, 6))
sns.histplot(laptop_df['Price'], bins=30, kde=True)
plt.title('Distribution of Laptop Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# Boxplot for 'Price'
plt.figure(figsize=(8, 6))
sns.boxplot(x=laptop_df['Price'])
plt.title('Boxplot of Laptop Prices')
plt.xlabel('Price')
plt.show()

# Bar chart for 'Brand'
plt.figure(figsize=(10, 6))
sns.countplot(y=laptop_df['Company'], order=laptop_df['Company'].value_counts().index)
plt.title('Number of Laptops by Brand')
plt.xlabel('Count')
plt.ylabel('Brand')
plt.show()
